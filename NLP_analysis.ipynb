# %% [markdown]
# # Import packages

# %%
import nltk
import pandas as pd
import os
import re
import string

# %% [markdown]
# # Read-in dataset

# %%
df = pd.read_excel('Cleaned/final/all_sessions.xlsx')

# %%
# Brief glance at data

df.head()
# Out:
#          Date                                           Question  \
# 0  2024-03-19  Have you heard of the crisis of reproducibility?:
# 1  2024-03-19  Have you heard of the crisis of reproducibility?:
# 2  2024-03-19  Have you heard of the crisis of reproducibility?:
# 3  2024-03-19  Have you heard of the crisis of reproducibility?:
# 4  2024-03-19  Have you heard of the crisis of reproducibility?:
#
#                               Response
# 0                    Yes, I think so.
# 1                    Yes, I think so.
# 2               No, I don't think so.
# 3               No, I don't think so.
# 4  Yes, and I have read all about it.

# %%
# Quick glance at questions - need to narrow down ones we want in wordcloud

df.Question.unique()
# Out:
# array(['Have you heard of the crisis of reproducibility?:',
#        'Have you tried to reproduce any research before?:',
#        'What did you try (or want to try) to repdroduce?:',
#        'Can you name some factors behind this crisis?:',
#        'Does the reproducibility crisis affect some researhers more than others?:',
#        'What impacts matter most to you?:',
#        'Why do these impacts affect some researchers more than others?:',
#        'What "soft fraud" or questionable research practicises have you seen/done/heard of?:',
#        'What makes researchers feel (especially) vulnerable:',
#        'What might reduce feelings of researcher vulnerability?:',
#        'Which of these reactions makes more sense to you?:',
#        'Do these proposed solutions make the vulnerability better or worse?:',
#        'Any additional thoughts on reproducibility in the "soft sciences"?:',
#        'Have you heard of GTD?:',
#        'What capture tools have you used or wanted to use?:',
#        'What can you tell us about how you combine and/or sort?:',
#        'What do you think is harder?:',
#        'What motivates or incentivises you?:',
#        'Which of these has frustrated you?:',
#        'Share some of collab wins and/or fails!:',
#        'Do your projects have a legacy plan?:',
#        'Have you ever asked a colleague to see any of their formal documents?:',
#        'What is the right level of sharing for this documentation?: A lab notebook',
#        'What is the right level of sharing for this documentation?: Meeting notes',
#        'What is the right level of sharing for this documentation?: Final code',
#        'What is the right level of sharing for this documentation?: Legacy plan',
#        'And again for this documentation?: Raw Data',
#        'And again for this documentation?: Code history',
#        'And again for this documentation?: Final and/or synthetic data',
#        'And again for this documentation?: Published article',
#        'Any more ideas about documentation?:',
#        'What tools do you like to use for teamwork?:',
#        'Share some of your technology wins and/or fails!:',
#        'Have you used git?:', 'What are your key git commands?:',
#        'What barriers stop you or your team from using code?:',
#        'What are the pros and cons of "data avilable on request"?:',
#        "If you can't share your data, describe it. What do you put in the description?:"],
#       dtype=object)

# %% [markdown]
# # Clean data

# %%
# Get rid of numerical answers

df = df[~df['Response'].astype(str).str.match(r'^\s*\d+\.?\d*\s*$')]

# %%
# Manually identified questions that don't include freetext responses
# Removed from dataset

df.Question.unique()
# Out:
# array(['Have you heard of the crisis of reproducibility?:',
#        'Have you tried to reproduce any research before?:',
#        'What did you try (or want to try) to repdroduce?:',
#        'Can you name some factors behind this crisis?:',
#        'Does the reproducibility crisis affect some researhers more than others?:',
#        'What impacts matter most to you?:',
#        'Why do these impacts affect some researchers more than others?:',
#        'What "soft fraud" or questionable research practicises have you seen/done/heard of?:',
#        'What makes researchers feel (especially) vulnerable:',
#        'What might reduce feelings of researcher vulnerability?:',
#        'Which of these reactions makes more sense to you?:',
#        'Do these proposed solutions make the vulnerability better or worse?:',
#        'Any additional thoughts on reproducibility in the "soft sciences"?:',
#        'Have you heard of GTD?:',
#        'What capture tools have you used or wanted to use?:',
#        'What can you tell us about how you combine and/or sort?:',
#        'What do you think is harder?:',
#        'What motivates or incentivises you?:',
#        'Which of these has frustrated you?:',
#        'Share some of collab wins and/or fails!:',
#        'Do your projects have a legacy plan?:',
#        'Have you ever asked a colleague to see any of their formal documents?:',
#        'Any more ideas about documentation?:',
#        'What tools do you like to use for teamwork?:',
#        'Share some of your technology wins and/or fails!:',
#        'Have you used git?:', 'What are your key git commands?:',
#        'What barriers stop you or your team from using code?:',
#        'What are the pros and cons of "data avilable on request"?:',
#        "If you can't share your data, describe it. What do you put in the description?:"],
#       dtype=object)

# %%
# Specify unwanted questions

unwanted_qs = ['Have you heard of the crisis of reproducibility?:', 'Have you tried to reproduce any research before?:', 'What did you try (or want to try) to repdroduce?:', 'Which of these reactions makes more sense to you?:', 'Have you heard of GTD?:', 'What do you think is harder?:', 'Do your projects have a legacy plan?:', 'Have you ever asked a colleague to see any of their formal documents?:', 'Have you used git?:']

# %%
# Subset based on unwanted questions - use tilde to specify we DON'T want this data

df = df[~df.Question.isin(unwanted_qs)].reset_index(drop = True)

# %%
df.Question.unique()
# Out:
# array(['Can you name some factors behind this crisis?:',
#        'Does the reproducibility crisis affect some researhers more than others?:',
#        'What impacts matter most to you?:',
#        'Why do these impacts affect some researchers more than others?:',
#        'What "soft fraud" or questionable research practicises have you seen/done/heard of?:',
#        'What makes researchers feel (especially) vulnerable:',
#        'What might reduce feelings of researcher vulnerability?:',
#        'Do these proposed solutions make the vulnerability better or worse?:',
#        'Any additional thoughts on reproducibility in the "soft sciences"?:',
#        'What capture tools have you used or wanted to use?:',
#        'What can you tell us about how you combine and/or sort?:',
#        'What motivates or incentivises you?:',
#        'Which of these has frustrated you?:',
#        'Share some of collab wins and/or fails!:',
#        'Any more ideas about documentation?:',
#        'What tools do you like to use for teamwork?:',
#        'Share some of your technology wins and/or fails!:',
#        'What are your key git commands?:',
#        'What barriers stop you or your team from using code?:',
#        'What are the pros and cons of "data avilable on request"?:',
#        "If you can't share your data, describe it. What do you put in the description?:"],
#       dtype=object)

# %% [markdown]
# # Pre-process data

# %%
# First, let's lowercase our string entries in response column
# We'll overwrite response column as this isn't a major change

df['Lower_cased'] = df['Response'].str.lower()

# %%
# Check it's worked..

df.head()
# Out:
#          Date                                           Question  \
# 0  2024-03-19     Can you name some factors behind this crisis?:
# 1  2024-03-19     Can you name some factors behind this crisis?:
# 2  2024-03-19     Can you name some factors behind this crisis?:
# 3  2024-03-19     Can you name some factors behind this crisis?:
# 4  2024-03-19  Does the reproducibility crisis affect some re...
#
#                                             Response  \
# 0                                  Code Data Methods
# 1                                          Ignorance
# 2                                pressure_to_publish
# 3                                               Data
# 4  Less emphasis in certain fields about document...
#
#                                          Lower_cased
# 0                                  code data methods
# 1                                          ignorance
# 2                                pressure_to_publish
# 3                                               data
# 4  less emphasis in certain fields about document...

# %%
# Replace "/" and "_" with " "
df['Cleaned_Response'] = df['Lower_cased'].str.replace('/', ' ', regex=False).str.replace('_', ' ', regex=False)

# %%
# Tokenise strings in response column
# Now, let's create a new column to preserve initial string entries

df['Tokenised'] = df.apply(lambda row: nltk.word_tokenize(row['Cleaned_Response']), axis=1)

# %%
df.head()
# Out:
#          Date                                           Question  \
# 0  2024-03-19     Can you name some factors behind this crisis?:
# 1  2024-03-19     Can you name some factors behind this crisis?:
# 2  2024-03-19     Can you name some factors behind this crisis?:
# 3  2024-03-19     Can you name some factors behind this crisis?:
# 4  2024-03-19  Does the reproducibility crisis affect some re...
#
#                                             Response  \
# 0                                  Code Data Methods
# 1                                          Ignorance
# 2                                pressure_to_publish
# 3                                               Data
# 4  Less emphasis in certain fields about document...
#
#                                          Lower_cased  \
# 0                                  code data methods
# 1                                          ignorance
# 2                                pressure_to_publish
# 3                                               data
# 4  less emphasis in certain fields about document...
#
#                                     Cleaned_Response  \
# 0                                  code data methods
# 1                                          ignorance
# 2                                pressure to publish
# 3                                               data
# 4  less emphasis in certain fields about document...
#
#                                            Tokenised
# 0                              [code, data, methods]
# 1                                        [ignorance]
# 2                            [pressure, to, publish]
# 3                                             [data]
# 4  [less, emphasis, in, certain, fields, about, d...

# %%
# Remove punctuation by defining translation table and applying it to tokenised lists in column
translator = str.maketrans('', '', string.punctuation)

df['Remove_punct'] = df['Tokenised'].apply(lambda tokens: [token.translate(translator) for token in tokens])

# %%
df.head(50)
# Out:
#           Date                                           Question  \
# 0   2024-03-19     Can you name some factors behind this crisis?:
# 1   2024-03-19     Can you name some factors behind this crisis?:
# 2   2024-03-19     Can you name some factors behind this crisis?:
# 3   2024-03-19     Can you name some factors behind this crisis?:
# 4   2024-03-19  Does the reproducibility crisis affect some re...
# 5   2024-03-19  Does the reproducibility crisis affect some re...
# 6   2024-03-19  Does the reproducibility crisis affect some re...
# 7   2024-03-19  Does the reproducibility crisis affect some re...
# 8   2024-03-19  Does the reproducibility crisis affect some re...
# 9   2024-03-19  Does the reproducibility crisis affect some re...
# 10  2024-03-19                  What impacts matter most to you?:
# 11  2024-03-19                  What impacts matter most to you?:
# 12  2024-03-19                  What impacts matter most to you?:
# 13  2024-03-19                  What impacts matter most to you?:
# 14  2024-03-19                  What impacts matter most to you?:
# 15  2024-03-19  Why do these impacts affect some researchers m...
# 16  2024-03-19  Why do these impacts affect some researchers m...
# 17  2024-03-19  What "soft fraud" or questionable research pra...
# 18  2024-03-19  What "soft fraud" or questionable research pra...
# 19  2024-03-19  What "soft fraud" or questionable research pra...
# 20  2024-03-19  What "soft fraud" or questionable research pra...
# 21  2024-03-19  What "soft fraud" or questionable research pra...
# 22  2024-03-19  What makes researchers feel (especially) vulne...
# 23  2024-03-19  What makes researchers feel (especially) vulne...
# 24  2024-03-19  What makes researchers feel (especially) vulne...
# 25  2024-03-19  What makes researchers feel (especially) vulne...
# 26  2024-03-19  What makes researchers feel (especially) vulne...
# 27  2024-03-19  What makes researchers feel (especially) vulne...
# 28  2024-03-19  What makes researchers feel (especially) vulne...
# 29  2024-03-19  What might reduce feelings of researcher vulne...
# 30  2024-03-19  What might reduce feelings of researcher vulne...
# 31  2024-03-19  What might reduce feelings of researcher vulne...
# 32  2024-03-19  What might reduce feelings of researcher vulne...
# 33  2024-03-19  What might reduce feelings of researcher vulne...
# 34  2024-03-19  What might reduce feelings of researcher vulne...
# 35  2024-03-19  Do these proposed solutions make the vulnerabi...
# 36  2024-03-19  Do these proposed solutions make the vulnerabi...
# 37  2024-03-19  Do these proposed solutions make the vulnerabi...
# 38  2024-03-19  Any additional thoughts on reproducibility in ...
# 39  2024-03-19  Any additional thoughts on reproducibility in ...
# 40  2024-03-19  Any additional thoughts on reproducibility in ...
# 41  2024-03-19  What capture tools have you used or wanted to ...
# 42  2024-03-19  What capture tools have you used or wanted to ...
# 43  2024-03-19  What capture tools have you used or wanted to ...
# 44  2024-03-19  What capture tools have you used or wanted to ...
# 45  2024-03-19  What capture tools have you used or wanted to ...
# 46  2024-03-19  What capture tools have you used or wanted to ...
# 47  2024-03-19  What capture tools have you used or wanted to ...
# 48  2024-03-19  What can you tell us about how you combine and...
# 49  2024-03-19  What can you tell us about how you combine and...
#
#                                              Response  \
# 0                                   Code Data Methods
# 1                                           Ignorance
# 2                                 pressure_to_publish
# 3                                                Data
# 4   Less emphasis in certain fields about document...
# 5                                    Lack of training
# 6   Less technological fields: literature for example
# 7                        Fear of research being taken
# 8                           The field of the research
# 9   Type of work; article, poster, paper, workshop...
# 10  Societal damage and impact on how people view ...
# 11                                  Trusting research
# 12                     Scientific progress slows down
# 13        bad research and 'corrupt' research culture
# 14  Reputation damage\nMiss understanding or miss use
# 15    removing inconvenient data points and p-hacking
# 16         norms and expectations in different fields
# 17    Removing inconvenient data points and p-hacking
# 18                                   MMR immunisation
# 19  Not reporting all results, removing extremes, ...
# 20              Manipulation of plots (x/y variables)
# 21                                          P-hacking
# 22  Imposter syndrome and fear of people seeing my...
# 23  Concern that you’ve done something wrong \n\nC...
# 24                                Calculation failure
# 25  reporting negative results, admitting the rese...
# 26                         Criticism\nImposer syndrom
# 27                               social vulnerability
# 28    Fear of critiquing or playing down the research
# 29  Mentorship from someone with experience in rep...
# 30                                      Good examples
# 31               Mentoring, good colleagues, practice
# 32        collaboration, having support of colleagues
# 33  Further training\nStart internal with sharing ...
# 34  Introduce these concepts at the undergraduate ...
# 35  Monetary incentives are quite powerful, and I ...
# 36                                             Relief
# 37  Yes, but it will take time for it to materialk...
# 38          Quali data partic difficult as you said .
# 39  Coding templates for publication, good practic...
# 40  Different journals ask for different things, d...
# 41  iPhone notes app, Word Docs (not the best meth...
# 42                                 Notes and whatsapp
# 43                                   Notion\nWhatssap
# 44                     Notes, clicking pics, calendar
# 45                                 notes app in phone
# 46                                        Taking pics
# 47                                             notion
# 48  Check task list at the start of every week and...
# 49        Large to do list for weekly and longer term
#
#                                           Lower_cased  \
# 0                                   code data methods
# 1                                           ignorance
# 2                                 pressure_to_publish
# 3                                                data
# 4   less emphasis in certain fields about document...
# 5                                    lack of training
# 6   less technological fields: literature for example
# 7                        fear of research being taken
# 8                           the field of the research
# 9   type of work; article, poster, paper, workshop...
# 10  societal damage and impact on how people view ...
# 11                                  trusting research
# 12                     scientific progress slows down
# 13        bad research and 'corrupt' research culture
# 14  reputation damage\nmiss understanding or miss use
# 15    removing inconvenient data points and p-hacking
# 16         norms and expectations in different fields
# 17    removing inconvenient data points and p-hacking
# 18                                   mmr immunisation
# 19  not reporting all results, removing extremes, ...
# 20              manipulation of plots (x/y variables)
# 21                                          p-hacking
# 22  imposter syndrome and fear of people seeing my...
# 23  concern that you’ve done something wrong \n\nc...
# 24                                calculation failure
# 25  reporting negative results, admitting the rese...
# 26                         criticism\nimposer syndrom
# 27                               social vulnerability
# 28    fear of critiquing or playing down the research
# 29  mentorship from someone with experience in rep...
# 30                                      good examples
# 31               mentoring, good colleagues, practice
# 32        collaboration, having support of colleagues
# 33  further training\nstart internal with sharing ...
# 34  introduce these concepts at the undergraduate ...
# 35  monetary incentives are quite powerful, and i ...
# 36                                             relief
# 37  yes, but it will take time for it to materialk...
# 38          quali data partic difficult as you said .
# 39  coding templates for publication, good practic...
# 40  different journals ask for different things, d...
# 41  iphone notes app, word docs (not the best meth...
# 42                                 notes and whatsapp
# 43                                   notion\nwhatssap
# 44                     notes, clicking pics, calendar
# 45                                 notes app in phone
# 46                                        taking pics
# 47                                             notion
# 48  check task list at the start of every week and...
# 49        large to do list for weekly and longer term
#
#                                      Cleaned_Response  \
# 0                                   code data methods
# 1                                           ignorance
# 2                                 pressure to publish
# 3                                                data
# 4   less emphasis in certain fields about document...
# 5                                    lack of training
# 6   less technological fields: literature for example
# 7                        fear of research being taken
# 8                           the field of the research
# 9   type of work; article, poster, paper, workshop...
# 10  societal damage and impact on how people view ...
# 11                                  trusting research
# 12                     scientific progress slows down
# 13        bad research and 'corrupt' research culture
# 14  reputation damage\nmiss understanding or miss use
# 15    removing inconvenient data points and p-hacking
# 16         norms and expectations in different fields
# 17    removing inconvenient data points and p-hacking
# 18                                   mmr immunisation
# 19  not reporting all results, removing extremes, ...
# 20              manipulation of plots (x y variables)
# 21                                          p-hacking
# 22  imposter syndrome and fear of people seeing my...
# 23  concern that you’ve done something wrong \n\nc...
# 24                                calculation failure
# 25  reporting negative results, admitting the rese...
# 26                         criticism\nimposer syndrom
# 27                               social vulnerability
# 28    fear of critiquing or playing down the research
# 29  mentorship from someone with experience in rep...
# 30                                      good examples
# 31               mentoring, good colleagues, practice
# 32        collaboration, having support of colleagues
# 33  further training\nstart internal with sharing ...
# 34  introduce these concepts at the undergraduate ...
# 35  monetary incentives are quite powerful, and i ...
# 36                                             relief
# 37  yes, but it will take time for it to materialk...
# 38          quali data partic difficult as you said .
# 39  coding templates for publication, good practic...
# 40  different journals ask for different things, d...
# 41  iphone notes app, word docs (not the best meth...
# 42                                 notes and whatsapp
# 43                                   notion\nwhatssap
# 44                     notes, clicking pics, calendar
# 45                                 notes app in phone
# 46                                        taking pics
# 47                                             notion
# 48  check task list at the start of every week and...
# 49        large to do list for weekly and longer term
#
#                                             Tokenised  \
# 0                               [code, data, methods]
# 1                                         [ignorance]
# 2                             [pressure, to, publish]
# 3                                              [data]
# 4   [less, emphasis, in, certain, fields, about, d...
# 5                                [lack, of, training]
# 6   [less, technological, fields, :, literature, f...
# 7                  [fear, of, research, being, taken]
# 8                     [the, field, of, the, research]
# 9   [type, of, work, ;, article, ,, poster, ,, pap...
# 10  [societal, damage, and, impact, on, how, peopl...
# 11                               [trusting, research]
# 12                [scientific, progress, slows, down]
# 13  [bad, research, and, 'corrupt, ', research, cu...
# 14  [reputation, damage, miss, understanding, or, ...
# 15  [removing, inconvenient, data, points, and, p-...
# 16  [norms, and, expectations, in, different, fields]
# 17  [removing, inconvenient, data, points, and, p-...
# 18                                [mmr, immunisation]
# 19  [not, reporting, all, results, ,, removing, ex...
# 20   [manipulation, of, plots, (, x, y, variables, )]
# 21                                        [p-hacking]
# 22  [imposter, syndrome, and, fear, of, people, se...
# 23  [concern, that, you, ’, ve, done, something, w...
# 24                             [calculation, failure]
# 25  [reporting, negative, results, ,, admitting, t...
# 26                      [criticism, imposer, syndrom]
# 27                            [social, vulnerability]
# 28  [fear, of, critiquing, or, playing, down, the,...
# 29  [mentorship, from, someone, with, experience, ...
# 30                                   [good, examples]
# 31      [mentoring, ,, good, colleagues, ,, practice]
# 32  [collaboration, ,, having, support, of, collea...
# 33  [further, training, start, internal, with, sha...
# 34  [introduce, these, concepts, at, the, undergra...
# 35  [monetary, incentives, are, quite, powerful, ,...
# 36                                           [relief]
# 37  [yes, ,, but, it, will, take, time, for, it, t...
# 38  [quali, data, partic, difficult, as, you, said...
# 39  [coding, templates, for, publication, ,, good,...
# 40  [different, journals, ask, for, different, thi...
# 41  [iphone, notes, app, ,, word, docs, (, not, th...
# 42                             [notes, and, whatsapp]
# 43                                 [notion, whatssap]
# 44            [notes, ,, clicking, pics, ,, calendar]
# 45                            [notes, app, in, phone]
# 46                                     [taking, pics]
# 47                                           [notion]
# 48  [check, task, list, at, the, start, of, every,...
# 49  [large, to, do, list, for, weekly, and, longer...
#
#                                          Remove_punct
# 0                               [code, data, methods]
# 1                                         [ignorance]
# 2                             [pressure, to, publish]
# 3                                              [data]
# 4   [less, emphasis, in, certain, fields, about, d...
# 5                                [lack, of, training]
# 6   [less, technological, fields, , literature, fo...
# 7                  [fear, of, research, being, taken]
# 8                     [the, field, of, the, research]
# 9   [type, of, work, , article, , poster, , paper,...
# 10  [societal, damage, and, impact, on, how, peopl...
# 11                               [trusting, research]
# 12                [scientific, progress, slows, down]
# 13  [bad, research, and, corrupt, , research, cult...
# 14  [reputation, damage, miss, understanding, or, ...
# 15  [removing, inconvenient, data, points, and, ph...
# 16  [norms, and, expectations, in, different, fields]
# 17  [removing, inconvenient, data, points, and, ph...
# 18                                [mmr, immunisation]
# 19  [not, reporting, all, results, , removing, ext...
# 20     [manipulation, of, plots, , x, y, variables, ]
# 21                                         [phacking]
# 22  [imposter, syndrome, and, fear, of, people, se...
# 23  [concern, that, you, ’, ve, done, something, w...
# 24                             [calculation, failure]
# 25  [reporting, negative, results, , admitting, th...
# 26                      [criticism, imposer, syndrom]
# 27                            [social, vulnerability]
# 28  [fear, of, critiquing, or, playing, down, the,...
# 29  [mentorship, from, someone, with, experience, ...
# 30                                   [good, examples]
# 31        [mentoring, , good, colleagues, , practice]
# 32  [collaboration, , having, support, of, colleag...
# 33  [further, training, start, internal, with, sha...
# 34  [introduce, these, concepts, at, the, undergra...
# 35  [monetary, incentives, are, quite, powerful, ,...
# 36                                           [relief]
# 37  [yes, , but, it, will, take, time, for, it, to...
# 38  [quali, data, partic, difficult, as, you, said, ]
# 39  [coding, templates, for, publication, , good, ...
# 40  [different, journals, ask, for, different, thi...
# 41  [iphone, notes, app, , word, docs, , not, the,...
# 42                             [notes, and, whatsapp]
# 43                                 [notion, whatssap]
# 44              [notes, , clicking, pics, , calendar]
# 45                            [notes, app, in, phone]
# 46                                     [taking, pics]
# 47                                           [notion]
# 48  [check, task, list, at, the, start, of, every,...
# 49  [large, to, do, list, for, weekly, and, longer...

# %%
# Special phrases and their possible variations
special_phrases = ["imposter syndrome", "to do list", "meta data", "p-hacking", "share point"]


import spacy
from spacy.matcher import Matcher

# Load SpaCy's English-language model
nlp = spacy.load("en_core_web_sm")

# Create the Matcher object and add the special phrases as patterns
matcher = Matcher(nlp.vocab)
for phrase in special_phrases:
    pattern = [{"LOWER": word} for word in phrase.split()]  # Create a pattern for the current phrase
    # Create a pattern for the current phrase
    matcher.add(phrase.upper().replace(" ", "_"), [pattern])  # Add the pattern to the matcher

    
def merge_phrases(tokens):
    # Join tokens to form a single string (necessary for SpaCy processing)
    text = " ".join(tokens)
    doc = nlp(text)
    matches = matcher(doc)
    with doc.retokenize() as retokenizer:
        for _, start, end in matches:
            retokenizer.merge(doc[start:end])

    # Extract the merged tokens from the doc
    merged_tokens = [token.text for token in doc]
    return merged_tokens

# %%
df['Phrases_pres'] = df['Remove_punct'].apply(merge_phrases)

# %%
df
# Out:
#            Date                                           Question  \
# 0    2024-03-19     Can you name some factors behind this crisis?:
# 1    2024-03-19     Can you name some factors behind this crisis?:
# 2    2024-03-19     Can you name some factors behind this crisis?:
# 3    2024-03-19     Can you name some factors behind this crisis?:
# 4    2024-03-19  Does the reproducibility crisis affect some re...
# ..          ...                                                ...
# 100  2024-03-19  If you can't share your data, describe it. Wha...
# 101  2024-03-19  If you can't share your data, describe it. Wha...
# 102  2024-03-19  If you can't share your data, describe it. Wha...
# 103  2024-03-19  If you can't share your data, describe it. Wha...
# 104  2024-03-19  If you can't share your data, describe it. Wha...
#
#                                               Response  \
# 0                                    Code Data Methods
# 1                                            Ignorance
# 2                                  pressure_to_publish
# 3                                                 Data
# 4    Less emphasis in certain fields about document...
# ..                                                 ...
# 100  Data collection method. Sample size. Variable ...
# 101                dimensions, type of variables, size
# 102   Type, scope, collection methods, visualisations?
# 103  We try to include a data template &/or data di...
# 104  Variables names with meta data, collection/sam...
#
#                                            Lower_cased  \
# 0                                    code data methods
# 1                                            ignorance
# 2                                  pressure_to_publish
# 3                                                 data
# 4    less emphasis in certain fields about document...
# ..                                                 ...
# 100  data collection method. sample size. variable ...
# 101                dimensions, type of variables, size
# 102   type, scope, collection methods, visualisations?
# 103  we try to include a data template &/or data di...
# 104  variables names with meta data, collection/sam...
#
#                                       Cleaned_Response  \
# 0                                    code data methods
# 1                                            ignorance
# 2                                  pressure to publish
# 3                                                 data
# 4    less emphasis in certain fields about document...
# ..                                                 ...
# 100  data collection method. sample size. variable ...
# 101                dimensions, type of variables, size
# 102   type, scope, collection methods, visualisations?
# 103  we try to include a data template & or data di...
# 104  variables names with meta data, collection sam...
#
#                                              Tokenised  \
# 0                                [code, data, methods]
# 1                                          [ignorance]
# 2                              [pressure, to, publish]
# 3                                               [data]
# 4    [less, emphasis, in, certain, fields, about, d...
# ..                                                 ...
# 100  [data, collection, method, ., sample, size, .,...
# 101      [dimensions, ,, type, of, variables, ,, size]
# 102  [type, ,, scope, ,, collection, methods, ,, vi...
# 103  [we, try, to, include, a, data, template, &, o...
# 104  [variables, names, with, meta, data, ,, collec...
#
#                                           Remove_punct  \
# 0                                [code, data, methods]
# 1                                          [ignorance]
# 2                              [pressure, to, publish]
# 3                                               [data]
# 4    [less, emphasis, in, certain, fields, about, d...
# ..                                                 ...
# 100  [data, collection, method, , sample, size, , v...
# 101        [dimensions, , type, of, variables, , size]
# 102  [type, , scope, , collection, methods, , visua...
# 103  [we, try, to, include, a, data, template, , or...
# 104  [variables, names, with, meta, data, , collect...
#
#                                           Phrases_pres
# 0                                [code, data, methods]
# 1                                          [ignorance]
# 2                              [pressure, to, publish]
# 3                                               [data]
# 4    [less, emphasis, in, certain, fields, about, d...
# ..                                                 ...
# 100  [data, collection, method,  , sample, size,  ,...
# 101      [dimensions,  , type, of, variables,  , size]
# 102  [type,  , scope,  , collection, methods,  , vi...
# 103  [we, try, to, include, a, data, template,  , o...
# 104  [variables, names, with, meta data,  , collect...
#
# [105 rows x 8 columns]

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download stopwords and wordnet resources from NLTK
nltk.download('stopwords')
nltk.download('wordnet')

# Initialize NLTK's lemmatizer and stop words set
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))


def process_text(word_list):
    # Remove stop words and lemmatize the remaining words
    return [lemmatizer.lemmatize(word) for word in word_list if word not in stop_words]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/loucap/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/loucap/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df['Rem_stop_words'] = df['Phrases_pres'].apply(process_text)

# %%
tokens = df['Rem_stop_words'].explode()

# Get value counts of each token
token_counts = tokens.value_counts()

print(token_counts)
# Out:
# Rem_stop_words
#                135
# data            12
# code            10
# research         9
# time             8
#               ...
# sticker          1
# planner          1
# reward           1
# feel             1
# aggregation      1
# Name: count, Length: 428, dtype: int64

# %%
tokens = df['Rem_stop_words'].explode()

# Get value counts of each token
token_counts = tokens.value_counts()

print(token_counts)
# Out:
# Rem_stop_words
#                135
# data            12
# code            10
# research         9
# time             8
#               ...
# sticker          1
# planner          1
# reward           1
# feel             1
# aggregation      1
# Name: count, Length: 428, dtype: int64

# %%
# Filter out rows with empty or whitespace-only strings, then explode
tokens = df['Rem_stop_words'][df['Rem_stop_words'].str.strip() != ''].explode()

# Get value counts of each token
token_counts = tokens.value_counts()

final = token_counts[1:,]

# %%
final.nlargest(40)
# Out:
# Rem_stop_words
# data             12
# code             10
# research          9
# time              8
# week              7
# variable          7
# project           6
# note              6
# documentation     6
# different         5
# etc               5
# using             5
# colleague         5
# use               5
# list              5
# method            5
# field             5
# good              4
# make              4
# set               4
# team              4
# task              4
# email             4
# notion            4
# document          4
# used              4
# git               4
# result            3
# journal           3
# reporting         3
# back              3
# phacking          3
# wait              3
# concern           3
# template          3
# version           3
# ’                 3
# wrong             3
# try               3
# old               3
# Name: count, dtype: int64

# %%
df.to_excel('test.xlsx', index = False)
